# %%
from pathlib import Path

EXP_DATA_PATH = Path("/Users/sebastian/Documents/PhD/Data/ThiolScreening/SEB_3XREPLICA/ExperimentalData/ExpData.csv")
COMP_TEST_DATA_PATH = Path("/Users/sebastian/Documents/PhD/Data/ThiolScreening/SEB_3XREPLICA/TestSet/COMBINED.csv")
COMP_TRAIN_DATA_PATH = Path("/Users/sebastian/Documents/PhD/Data/ThiolScreening/SEB_3XREPLICA/TrainingSet/TRAIN_ALL.csv")
REPLICAS = [1]
T_exp = 273.15 + 25
RT_exp = T_exp * 8.314 / (4.184 * 1000)  # kcal/mol
T_comp = 300
RT_comp = T_comp * 8.314 / (4.184 * 1000)  # kcal/mol

# %%
import pandas as pd

# the Numbers app saved the CSV with semicolons
# I editted the CSV to include Andreas KA's for the   test set
exp_data = pd.read_csv(EXP_DATA_PATH, skiprows=4, delimiter=";", index_col="Name")  
exp_data.index = pd.Index(map(lambda x: x.upper(), exp_data.index))
exp_data.loc[:, "DG (kcal/mol)"] = exp_data.loc[:, "delta G exp (kJ/mol)"] / 4.184
exp_data.loc[:, "DG std (kcal/mol)"] = exp_data.loc[:, "delta G exp std"] / 4.184
exp_data.drop(labels=["delta G exp (kJ/mol)", "delta G exp std"], axis="columns", inplace=True)
exp_data.head()
# Out:
#       Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# N1A19         Train     2200000.0    100000.0          -8.71
# N2A19         Train     1300000.0    100000.0          -8.39
# N1A18         Train      610000.0    140000.0          -7.94
# N2A18         Train      510000.0     30000.0          -7.83
# N1A11         Train      480000.0     50000.0          -7.80
#
#        DG std (kcal/mol)
# N1A19               0.03
# N2A19               0.04
# N1A18               0.12
# N2A18               0.03
# N1A11               0.06

# %%
exp_data.sort_values(by="DG (kcal/mol)")
# Out:
#         Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# N1A19           Train     2200000.0    100000.0      -8.710000
# N2A19           Train     1300000.0    100000.0      -8.390000
# N1A18           Train      610000.0    140000.0      -7.940000
# N2A18           Train      510000.0     30000.0      -7.830000
# N1A11           Train      480000.0     50000.0      -7.800000
# N1A14           Train      460000.0         0.0      -7.770000
# N1A10           Train      410000.0     40000.0      -7.700000
# N1A12           Train      390000.0     30000.0      -7.670000
# N1A15           Train      370000.0         0.0      -7.640000
# N3A19           Train      360000.0     10000.0      -7.630000
# N1A1            Train      360000.0         0.0      -7.630000
# N1A13           Train      270000.0     30000.0      -7.460000
# N1A7            Train      260000.0     60000.0      -7.430000
# N1A8            Train      130000.0     20000.0      -7.020000
# N1A9            Train      120000.0     20000.0      -6.970000
# N2A10           Train       93000.0     12000.0      -6.820000
# N2A11           Train       85000.0     15000.0      -6.770000
# N13A20          Train       50000.0         0.0      -6.450000
# N16A20          Train       45000.0         0.0      -6.390000
# PRO-LEU          Test       11580.0      3056.0      -5.544933
# PHE-SER          Test        5673.0      5018.0      -5.114723
# PHE-LEU          Test        4747.0      1711.0      -5.019120
# GLY-ILE          Test        4184.0      2793.0      -4.947419
# GLN-GLN          Test        3367.0      1214.0      -4.804015
# PRO-PRO          Test        2917.0      1061.0      -4.732314
# PRO-ALA          Test        2532.0      1072.0      -4.636711
# TRP-GLN          Test        2512.0      1163.0      -4.636711
# GLN-ALA          Test        2550.0       986.0      -4.636711
# LEU-LEU          Test        2120.0       958.0      -4.517208
# N7A20           Train        1100.0         0.0      -4.170000
# N15A20          Train         300.0         0.0      -3.400000
# N6A20           Train         120.0         5.0      -2.850000
# N9A20           Train           0.0         0.0       0.000000
# N14A20          Train           0.0         0.0       0.000000
# N8A20           Train           0.0         0.0       0.000000
# N1A16           Train           0.0         0.0       0.000000
# N1A17           Train           0.0         0.0       0.000000
# N3A10           Train           0.0         0.0       0.000000
# N3A11           Train           0.0         0.0       0.000000
# N3A18           Train           0.0         0.0       0.000000
# N6A21           Train           0.0         0.0       0.000000
#
#          DG std (kcal/mol)
# N1A19             0.030000
# N2A19             0.040000
# N1A18             0.120000
# N2A18             0.030000
# N1A11             0.060000
# N1A14             0.000000
# N1A10             0.060000
# N1A12             0.040000
# N1A15             0.000000
# N3A19             0.020000
# N1A1              0.000000
# N1A13             0.060000
# N1A7              0.120000
# N1A8              0.090000
# N1A9              0.090000
# N2A10             0.070000
# N2A11             0.100000
# N13A20            0.000000
# N16A20            0.000000
# PRO-LEU           0.143403
# PHE-SER           0.788719
# PHE-LEU           0.382409
# GLY-ILE           0.788719
# GLN-GLN           0.525813
# PRO-PRO           0.597514
# PRO-ALA           0.764818
# TRP-GLN           0.860421
# GLN-ALA           0.693117
# LEU-LEU           0.956023
# N7A20             0.000000
# N15A20            0.000000
# N6A20             0.020000
# N9A20             0.000000
# N14A20            0.000000
# N8A20             0.000000
# N1A16             0.000000
# N1A17             0.000000
# N3A10             0.000000
# N3A11             0.000000
# N3A18             0.000000
# N6A21             0.000000

# %%
def import_clean_data(full_path: Path, replicas: list[int]) -> pd.DataFrame:
    rename_col_map = {f"DG{i}": f"W{i}"  for j in replicas for i in range(1 + 10 * (j - 1), 11 + 10 * (j - 1))}
    data = pd.read_csv(full_path, index_col="Names")
    data.index = pd.Index(map(lambda x: x.upper(), data.index))
    data.rename(columns=rename_col_map, inplace=True)
    data = data.loc[:, list(rename_col_map.values())]
    raw_scores_cols = list(rename_col_map.values())
    data.loc[:, "W Q1"] = data.loc[:, raw_scores_cols].quantile(0.25, axis=1)
    data.loc[:, "W Q2"] = data.loc[:, raw_scores_cols].quantile(0.50, axis=1)
    data.loc[:, "W Q3"] = data.loc[:, raw_scores_cols].quantile(0.75, axis=1)
    data.loc[:, "W mean"] = data.loc[:, raw_scores_cols].mean(axis=1)
    data.loc[:, "W std"] = data.loc[:, raw_scores_cols].std(axis=1)
    data.loc[:, "W Q2 - Q1"] = data.loc[:, "W Q2"] - data.loc[:, "W Q1"]
    data.loc[:, "W Q3 - Q2"] = data.loc[:, "W Q3"] - data.loc[:, "W Q2"]
    data.loc[:, "W sem"] = data.loc[:, [f"W{i}" for j in replicas for i in range(1 + 10 * (j - 1), 11 + 10 * (j - 1))]].sem(axis=1)
    return data

train_data = import_clean_data(full_path=COMP_TRAIN_DATA_PATH, replicas=REPLICAS)
test_data = import_clean_data(full_path=COMP_TEST_DATA_PATH, replicas=REPLICAS)
print(f"Training data {train_data.shape}")
display(train_data.head())
print(f"Test data {test_data.shape}")
display(test_data.head())
# Out:
# Training data (31, 18)
#               W1        W2        W3        W4         W5        W6  \
# N8A20  -3.039702 -3.350013 -5.757586 -3.700962  -0.975152 -6.154782
# N14A20 -6.557702 -6.606248 -5.085371 -5.779350  -6.569012 -1.326767
# N9A20  -4.534875 -6.070220 -9.892054 -8.018716  -4.992964 -9.586105
# N6A21  -2.817172 -3.525729 -2.030332 -6.446197  -1.118205 -1.671448
# N1A16  -9.761506 -5.034735 -2.751264 -8.977035 -13.011354 -7.382005
#
#                W7         W8         W9        W10       W Q1      W Q2  \
# N8A20   -8.395298  -1.975929  -5.838305  -7.085434  -6.075663 -4.729274
# N14A20  -2.631706 -11.335538  -6.624292  -8.428724  -6.619781 -6.563357
# N9A20   -2.401261  -6.460095  -1.100079 -12.434936  -9.194258 -6.265158
# N6A21   -3.674760  -4.955794  -4.900371  -5.263954  -4.941938 -3.600245
# N1A16  -10.790537  -9.003900 -10.681622  -6.475542 -10.451593 -8.990468
#
#             W Q3    W mean     W std  W Q2 - Q1  W Q3 - Q2     W sem
# N8A20  -3.117280 -4.627316  2.373359   1.346389   1.611994  0.750522
# N14A20 -5.258866 -6.094471  2.783667   0.056425   1.304491  0.880273
# N9A20  -4.649398 -6.549131  3.508939   2.929100   1.615760  1.109624
# N6A21  -2.227042 -3.640396  1.743203   1.341694   1.373202  0.551249
# N1A16  -6.702158 -8.386950  3.031461   1.461126   2.288310  0.958632
# Test data (100, 18)
#                 W1         W2         W3         W4         W5         W6  \
# ALA-ALA  -6.961015 -20.808203  -7.672737 -14.056838 -13.880766 -21.542746
# ALA-GLN -14.921901  -9.921203 -23.765848 -22.499543 -13.971522 -17.719784
# ALA-GLY -12.625892 -21.574269 -28.030733 -18.877305 -10.081222 -13.035510
# ALA-ILE  -9.933800 -10.666534 -15.712166 -15.695068 -21.260663 -13.463368
# ALA-LEU -19.332221 -11.277302 -13.858082 -17.799789 -24.808623  -9.658209
#
#                 W7         W8         W9        W10       W Q1       W Q2  \
# ALA-ALA -17.076709  -8.989639  -7.951800 -13.476101 -16.321741 -13.678434
# ALA-GLN -12.864437  -9.950798  -8.683790 -14.625605 -17.020313 -14.298564
# ALA-GLY  -9.640001  -8.362615 -11.142763 -16.238575 -18.217622 -12.830701
# ALA-ILE -14.505901 -22.820153 -14.082500 -16.889608 -16.595248 -15.100485
# ALA-LEU -10.933035 -16.168872 -11.243834 -19.496898 -18.949113 -15.013477
#
#               W Q3     W mean     W std  W Q2 - Q1  W Q3 - Q2     W sem
# ALA-ALA  -8.211260 -13.241656  5.359497   2.643307   5.467174  1.694822
# ALA-GLN -10.679208 -14.892443  5.134984   2.721750   3.619356  1.623825
# ALA-GLY -10.346607 -14.960889  6.244340   5.386921   2.484094  1.974634
# ALA-ILE -13.618151 -15.502976  4.086213   1.494763   1.482334  1.292174
# ALA-LEU -11.252201 -15.457687  4.906411   3.935636   3.761276  1.551543

# %%
train_data.loc[:, ["W Q2", "W sem"]].sort_values(by="W Q2")
# Out:
#              W Q2     W sem
# N2A19  -20.900969  1.480912
# N3A19  -19.296454  2.065200
# N16A20 -17.107837  0.688337
# N1A19  -15.618125  1.850858
# N1A9   -14.493513  0.973860
# N1A13  -14.472387  1.040124
# N1A14  -14.374322  1.014319
# N1A12  -13.677958  1.667704
# N3A18  -13.653623  1.222408
# N2A11  -13.638049  1.264303
# N1A18  -13.493801  1.054028
# N1A10  -13.139497  1.034049
# N1A11  -12.590271  0.666999
# N1A7   -12.386254  1.054875
# N2A10  -11.637769  0.981857
# N2A18  -11.619795  1.155909
# N3A11  -11.177808  1.467411
# N1A15  -10.464083  0.563246
# N3A10  -10.389740  1.504568
# N1A8   -10.199828  1.189135
# N1A1    -9.437938  0.708314
# N1A16   -8.990468  0.958632
# N7A20   -6.810354  0.796436
# N14A20  -6.563357  0.880273
# N9A20   -6.265158  1.109624
# N1A17   -5.763703  0.647613
# N15A20  -5.400724  0.637206
# N13A20  -5.327355  0.939665
# N6A20   -5.176643  0.759553
# N8A20   -4.729274  0.750522
# N6A21   -3.600245  0.551249

# %%
from typing import Literal


def select_exp_data(exp_data: pd.DataFrame, selection: Literal["Train", "Test"], only_active: bool = True) -> pd.DataFrame:
    selected_data = exp_data.loc[exp_data.loc[:, "Training/Test"] == selection, :]
    if only_active is True:
        return selected_data.loc[selected_data.loc[:, "DG (kcal/mol)"] != 0.0, :]
    return selected_data

# %% [markdown]
# # Training Set

# %%
exp_train_active = select_exp_data(exp_data=exp_data, selection="Train", only_active=True)
print(f"Experimental data, Training set, active dyads {exp_train_active.shape}")
exp_train_active.head()
# Out:
# Experimental data, Training set, active dyads (22, 5)
#       Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# N1A19         Train     2200000.0    100000.0          -8.71
# N2A19         Train     1300000.0    100000.0          -8.39
# N1A18         Train      610000.0    140000.0          -7.94
# N2A18         Train      510000.0     30000.0          -7.83
# N1A11         Train      480000.0     50000.0          -7.80
#
#        DG std (kcal/mol)
# N1A19               0.03
# N2A19               0.04
# N1A18               0.12
# N2A18               0.03
# N1A11               0.06

# %%
# train_data.loc[:, ["W Q2", "W sem"]].sort_values(by="W Q2")
exp_data.loc[train_data.index].join(train_data.loc[:, ["W Q2", "W sem"]]).sort_values(by="DG (kcal/mol)")
# Out:
#        Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# N1A19          Train     2200000.0    100000.0          -8.71
# N2A19          Train     1300000.0    100000.0          -8.39
# N1A18          Train      610000.0    140000.0          -7.94
# N2A18          Train      510000.0     30000.0          -7.83
# N1A11          Train      480000.0     50000.0          -7.80
# N1A14          Train      460000.0         0.0          -7.77
# N1A10          Train      410000.0     40000.0          -7.70
# N1A12          Train      390000.0     30000.0          -7.67
# N1A15          Train      370000.0         0.0          -7.64
# N3A19          Train      360000.0     10000.0          -7.63
# N1A1           Train      360000.0         0.0          -7.63
# N1A13          Train      270000.0     30000.0          -7.46
# N1A7           Train      260000.0     60000.0          -7.43
# N1A8           Train      130000.0     20000.0          -7.02
# N1A9           Train      120000.0     20000.0          -6.97
# N2A10          Train       93000.0     12000.0          -6.82
# N2A11          Train       85000.0     15000.0          -6.77
# N13A20         Train       50000.0         0.0          -6.45
# N16A20         Train       45000.0         0.0          -6.39
# N7A20          Train        1100.0         0.0          -4.17
# N15A20         Train         300.0         0.0          -3.40
# N6A20          Train         120.0         5.0          -2.85
# N3A18          Train           0.0         0.0           0.00
# N3A11          Train           0.0         0.0           0.00
# N3A10          Train           0.0         0.0           0.00
# N1A17          Train           0.0         0.0           0.00
# N1A16          Train           0.0         0.0           0.00
# N6A21          Train           0.0         0.0           0.00
# N9A20          Train           0.0         0.0           0.00
# N14A20         Train           0.0         0.0           0.00
# N8A20          Train           0.0         0.0           0.00
#
#         DG std (kcal/mol)       W Q2     W sem
# N1A19                0.03 -15.618125  1.850858
# N2A19                0.04 -20.900969  1.480912
# N1A18                0.12 -13.493801  1.054028
# N2A18                0.03 -11.619795  1.155909
# N1A11                0.06 -12.590271  0.666999
# N1A14                0.00 -14.374322  1.014319
# N1A10                0.06 -13.139497  1.034049
# N1A12                0.04 -13.677958  1.667704
# N1A15                0.00 -10.464083  0.563246
# N3A19                0.02 -19.296454  2.065200
# N1A1                 0.00  -9.437938  0.708314
# N1A13                0.06 -14.472387  1.040124
# N1A7                 0.12 -12.386254  1.054875
# N1A8                 0.09 -10.199828  1.189135
# N1A9                 0.09 -14.493513  0.973860
# N2A10                0.07 -11.637769  0.981857
# N2A11                0.10 -13.638049  1.264303
# N13A20               0.00  -5.327355  0.939665
# N16A20               0.00 -17.107837  0.688337
# N7A20                0.00  -6.810354  0.796436
# N15A20               0.00  -5.400724  0.637206
# N6A20                0.02  -5.176643  0.759553
# N3A18                0.00 -13.653623  1.222408
# N3A11                0.00 -11.177808  1.467411
# N3A10                0.00 -10.389740  1.504568
# N1A17                0.00  -5.763703  0.647613
# N1A16                0.00  -8.990468  0.958632
# N6A21                0.00  -3.600245  0.551249
# N9A20                0.00  -6.265158  1.109624
# N14A20               0.00  -6.563357  0.880273
# N8A20                0.00  -4.729274  0.750522

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np

y = exp_train_active.loc[:, "DG (kcal/mol)"].abs()
for replicas in [[1], [2], [3], [1, 2], [1, 3], [2, 3], [1, 2, 3]]:
    train_data_temp = import_clean_data(full_path=COMP_TRAIN_DATA_PATH, replicas=replicas)
    for fit_col in ["W Q2", "W mean"]:
        print(f"Replicas: {replicas}, fit column: {fit_col}")
        x = train_data_temp.loc[y.index, fit_col].abs()
        slope, intercept, r_value, *_ = linregress(x, y)
        print(f"\ty = {slope:.2f}x + {intercept:.2f}, R2 = {r_value**2:.2f}")
        ratio = (y / x).mean()
        print(f"\t∂G_exp/W: {ratio:.2f}")
# Out:
# Replicas: [1], fit column: W Q2
# 	y = 0.26x + 3.78, R2 = 0.49
# 	∂G_exp/W: 0.60
# Replicas: [1], fit column: W mean
# 	y = 0.25x + 3.79, R2 = 0.52
# 	∂G_exp/W: 0.59
# Replicas: [2], fit column: W Q2
# 	y = 0.25x + 3.88, R2 = 0.51
# 	∂G_exp/W: 0.62
# Replicas: [2], fit column: W mean
# 	y = 0.26x + 3.69, R2 = 0.52
# 	∂G_exp/W: 0.60
# Replicas: [3], fit column: W Q2
# 	y = 0.27x + 3.61, R2 = 0.57
# 	∂G_exp/W: 0.62
# Replicas: [3], fit column: W mean
# 	y = 0.27x + 3.57, R2 = 0.57
# 	∂G_exp/W: 0.60
# Replicas: [1, 2], fit column: W Q2
# 	y = 0.26x + 3.72, R2 = 0.52
# 	∂G_exp/W: 0.61
# Replicas: [1, 2], fit column: W mean
# 	y = 0.27x + 3.63, R2 = 0.54
# 	∂G_exp/W: 0.59
# Replicas: [1, 3], fit column: W Q2
# 	y = 0.27x + 3.62, R2 = 0.54
# 	∂G_exp/W: 0.61
# Replicas: [1, 3], fit column: W mean
# 	y = 0.27x + 3.57, R2 = 0.56
# 	∂G_exp/W: 0.59
# Replicas: [2, 3], fit column: W Q2
# 	y = 0.27x + 3.72, R2 = 0.55
# 	∂G_exp/W: 0.62
# Replicas: [2, 3], fit column: W mean
# 	y = 0.27x + 3.55, R2 = 0.56
# 	∂G_exp/W: 0.60
# Replicas: [1, 2, 3], fit column: W Q2
# 	y = 0.27x + 3.64, R2 = 0.55
# 	∂G_exp/W: 0.61
# Replicas: [1, 2, 3], fit column: W mean
# 	y = 0.27x + 3.54, R2 = 0.56
# 	∂G_exp/W: 0.59

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np 

train_col = "W Q2"
train_col_err = ["W sem"] #["W Q2 - Q1", "W Q3 - Q2"]
y = exp_train_active.loc[:, "DG (kcal/mol)"]
y_err = exp_train_active.loc[:, "DG std (kcal/mol)"]
x = train_data.loc[y.index, train_col]
x_err = train_data.loc[y.index, train_col_err].T

x_range_min = -30
y_range_min = -10
slope, intercept , r_value, *_ = linregress(x, y)
space = np.linspace(0, x_range_min, 3)
print(f"y = {slope:.2f}x + {intercept:.2f}, R2 = {r_value**2:.2f}")

FONTSIZE = 14
BLUE = (0.0, 0.4, 0.8)
fig, ax = plt.subplots(figsize=(6, 4))
ax.errorbar(x=x, y=y, xerr=x_err, yerr=y_err, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
ax.plot(space, intercept + slope * space, color="k", linestyle="--", label=f"y = {slope:.2f}x - {abs(intercept):.2f}"+ "\n" +  fr"$R^2$ = {r_value**2:.2f}")
ax.tick_params(labelsize=FONTSIZE, direction="in", length=5, width=1)
ax.set_xlabel(r"$W$ (kCal / mol)", fontsize=FONTSIZE)
ax.set_ylabel(r"$\Delta G_{exp}$ (kCal / mol)", fontsize=FONTSIZE)
ax.set_xlim(x_range_min, 0)
ax.set_ylim(y_range_min)
ax.legend(loc="lower left", fontsize=FONTSIZE - 2, bbox_to_anchor=[0.55,0.03,1,0.2])
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax2 = plt.axes([0.23, 0.65, 0.3, 0.25])
ax2.errorbar(x=range(len(x)), y=y/x, fmt="o", ms=4, color=BLUE)
ax2.set_xlim(-1, len(x) + 1)
ax2.set_xlabel("Diad ID", fontsize=FONTSIZE - 2)
ax2.set_ylabel(r"$\Delta G_{exp}$/ $W$", fontsize=FONTSIZE - 2)
ax2.tick_params(labelsize=FONTSIZE - 2, direction="in", length=5, width=1)
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0, 1])
ax2.axhline((y/x).mean(), linestyle="-", color="gray", lw=1)
ratio = (y/x).mean()
print(f"∂G_exp/W: {ratio:.2f}")
plt.savefig("training_set_fit.png", format="png", dpi=300, bbox_inches="tight")
plt.savefig("training_set_fit.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()
plt.close()
# Out:
# y = 0.26x + -3.78, R2 = 0.49
# ∂G_exp/W: 0.60

# %%
def score_to_dg(score):
    return slope * score + intercept

# %% [markdown]
# # Test Set

# %%
exp_test = select_exp_data(exp_data=exp_data, selection="Test", only_active=False)
exp_test
# Out:
#         Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# PRO-LEU          Test       11580.0      3056.0      -5.544933
# PHE-SER          Test        5673.0      5018.0      -5.114723
# GLY-ILE          Test        4184.0      2793.0      -4.947419
# PRO-PRO          Test        2917.0      1061.0      -4.732314
# PHE-LEU          Test        4747.0      1711.0      -5.019120
# LEU-LEU          Test        2120.0       958.0      -4.517208
# TRP-GLN          Test        2512.0      1163.0      -4.636711
# PRO-ALA          Test        2532.0      1072.0      -4.636711
# GLN-GLN          Test        3367.0      1214.0      -4.804015
# GLN-ALA          Test        2550.0       986.0      -4.636711
#
#          DG std (kcal/mol)
# PRO-LEU           0.143403
# PHE-SER           0.788719
# GLY-ILE           0.788719
# PRO-PRO           0.597514
# PHE-LEU           0.382409
# LEU-LEU           0.956023
# TRP-GLN           0.860421
# PRO-ALA           0.764818
# GLN-GLN           0.525813
# GLN-ALA           0.693117

# %%
# extract amino acids from index
test_data.loc[:, "aa1"] = list(map(lambda x: x.split("-")[0], test_data.index))
test_data.loc[:, "aa2"] = list(map(lambda x: x.split("-")[1], test_data.index))
# convert scores (and stds or quartiles) to "∂G" values (namely adjusted scores) and KAs
cols_to_adjust = ["W Q1", "W Q2", "W Q3", "W mean"]
cols_adjusted = [f"{col}_adj" for col in cols_to_adjust]
for col_before, col_after in zip(cols_to_adjust, cols_adjusted, strict=True):
    test_data.loc[:, col_after] = test_data.loc[:, col_before].apply(score_to_dg)
cols_transformed = [f"KA {col}" for col in cols_adjusted]
for col_before, col_after in zip(cols_adjusted, cols_transformed, strict=True):
    test_data.loc[:, col_after] = np.exp(test_data.loc[:, col_before].abs() / RT_comp)
test_data.loc[:, "W Q2 - Q1_adj"] = (test_data.loc[:, "W Q2_adj"] - test_data.loc[:, "W Q1_adj"]).abs()
test_data.loc[:, "W Q3 - Q2_adj"] = (test_data.loc[:, "W Q3_adj"] - test_data.loc[:, "W Q2_adj"]).abs()
test_data.loc[:, "KA W Q2 - Q1_adj"] = (test_data.loc[:, "KA W Q2_adj"] - test_data.loc[:, "KA W Q1_adj"]).abs()
test_data.loc[:, "KA W Q3 - Q2_adj"] = (test_data.loc[:, "KA W Q3_adj"] - test_data.loc[:, "KA W Q2_adj"]).abs()
test_data.loc[:, "rank"] = test_data.loc[:, "KA W Q2_adj"].rank(axis="index", ascending=False)
test_data.loc[exp_test.index].iloc[:, 20:]
# Out:
#          W Q1_adj  W Q2_adj  W Q3_adj  W mean_adj   KA W Q1_adj   KA W Q2_adj  \
# PRO-LEU -8.543547 -8.385390 -8.124019   -8.280392  1.675680e+06  1.285198e+06
# PHE-SER -8.529628 -7.925024 -7.445467   -7.719413  1.637009e+06  5.937196e+05
# GLY-ILE -8.335095 -8.103582 -7.208509   -7.936499  1.181215e+06  8.010606e+05
# PRO-PRO -8.796182 -7.795544 -7.057511   -8.086749  2.560014e+06  4.778062e+05
# PHE-LEU -8.123524 -7.386973 -6.778995   -7.503667  8.283118e+05  2.407672e+05
# LEU-LEU -8.024905 -7.726419 -6.710109   -8.024744  7.020170e+05  4.254936e+05
# TRP-GLN -8.539869 -7.755421 -6.806989   -8.018136  1.665374e+06  4.467054e+05
# PRO-ALA -8.218457 -7.637043 -6.970022   -7.596981  9.713034e+05  3.662522e+05
# GLN-GLN -9.266238 -8.060371 -7.112350   -8.398642  5.632350e+06  7.450499e+05
# GLN-ALA -8.145166 -7.600094 -6.332203   -7.284753  8.589356e+05  3.442404e+05
#
#            KA W Q3_adj  KA W mean_adj  W Q2 - Q1_adj  W Q3 - Q2_adj  \
# PRO-LEU  829000.130649   1.077647e+06       0.158157       0.261371
# PHE-SER  265590.281230   4.205219e+05       0.604604       0.479557
# GLY-ILE  178477.069159   6.052586e+05       0.231513       0.895072
# PRO-PRO  138540.269075   7.787578e+05       1.000638       0.738033
# PHE-LEU   86830.098435   2.928278e+05       0.736551       0.607978
# LEU-LEU   77354.437609   7.018266e+05       0.298486       1.016310
# TRP-GLN   91004.873422   6.940903e+05       0.784448       0.948432
# PRO-ALA  119629.508834   3.424471e+05       0.581414       0.667021
# GLN-GLN  151889.399812   1.314086e+06       1.205866       0.948022
# GLN-ALA   41036.530445   2.028279e+05       0.545072       1.267892
#
#          KA W Q2 - Q1_adj  KA W Q3 - Q2_adj  rank
# PRO-LEU      3.904821e+05     456197.506373   6.0
# PHE-SER      1.043289e+06     328129.316448  21.0
# GLY-ILE      3.801541e+05     622583.549036  12.0
# PRO-PRO      2.082208e+06     339265.886333  35.0
# PHE-LEU      5.875446e+05     153937.128445  62.0
# LEU-LEU      2.765234e+05     348139.136311  40.0
# TRP-GLN      1.218669e+06     355700.564350  39.0
# PRO-ALA      6.050512e+05     246622.707234  43.0
# GLN-GLN      4.887300e+06     593160.549885  14.0
# GLN-ALA      5.146951e+05     303203.919257  47.0

# %%
exp_test
# Out:
#         Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# PRO-LEU          Test       11580.0      3056.0      -5.544933
# PHE-SER          Test        5673.0      5018.0      -5.114723
# GLY-ILE          Test        4184.0      2793.0      -4.947419
# PRO-PRO          Test        2917.0      1061.0      -4.732314
# PHE-LEU          Test        4747.0      1711.0      -5.019120
# LEU-LEU          Test        2120.0       958.0      -4.517208
# TRP-GLN          Test        2512.0      1163.0      -4.636711
# PRO-ALA          Test        2532.0      1072.0      -4.636711
# GLN-GLN          Test        3367.0      1214.0      -4.804015
# GLN-ALA          Test        2550.0       986.0      -4.636711
#
#          DG std (kcal/mol)
# PRO-LEU           0.143403
# PHE-SER           0.788719
# GLY-ILE           0.788719
# PRO-PRO           0.597514
# PHE-LEU           0.382409
# LEU-LEU           0.956023
# TRP-GLN           0.860421
# PRO-ALA           0.764818
# GLN-GLN           0.525813
# GLN-ALA           0.693117

# %%
test_col = "W Q2_adj"
test_col_err = ["W sem"] # ["W Q2 - Q1_adj", "W Q3 - Q2_adj"]

y = exp_test.loc[:, "DG (kcal/mol)"]
y_err = exp_test.loc[:, "DG std (kcal/mol)"]
x = test_data.loc[y.index, test_col]
x_err = test_data.loc[y.index, test_col_err].T


x_range_min, x_range_max = -9, -7
y_range_min, y_range_max = -6, -4
slope_, intercept_, r_value_, *_ = linregress(x, y)
space = np.linspace(x_range_min, x_range_max, 3)
print(f"y = {slope_:.2f}x + {intercept_:.2f}, R2 = {r_value_**2:.2f}")

FONTSIZE = 14
BLUE = (0.0, 0.4, 0.8)
fig, ax = plt.subplots(figsize=(4, 3))
# ax.errorbar(x=x, y=y, xerr=x_err, yerr=y_err, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
ax.errorbar(x=x, y=y, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
ax.plot(
    space, intercept_ + slope_ * space,
    color="k", linestyle="--",
    label=f"y = {slope_:.2f}x - {abs(intercept_):.2f}",
)
ax.tick_params(labelsize=FONTSIZE, direction="in", length=5, width=1)
ax.set_xlabel(r"$W_{adj}$ (kCal / mol)", fontsize=FONTSIZE)
ax.set_ylabel(r"$\Delta G_{exp}$ (kCal / mol)", fontsize=FONTSIZE)
ax.set_xlim(x_range_min, x_range_max)
ax.set_ylim(y_range_min, y_range_max)
# ax.legend(loc="best", fontsize=FONTSIZE - 2, bbox_to_anchor=[0.02, 0.9, 1, 0.2])
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
# consider using a bootstraped standard error for the computational values, instead of the standard deviation
plt.savefig("gexp_vs_gcomp.png", format="png", dpi=300, bbox_inches="tight")
plt.savefig("gexp_vs_gcomp.svg", format="svg", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# y = 0.66x + 0.34, R2 = 0.39

# %%
y = exp_test.loc[:, "KA exp (1/M)"].abs()
y_err = exp_test.loc[:, "KA exp std"]
x = test_data.loc[y.index, "rank"].abs()

# x_range_min, x_range_max = 0, 100
# y_range_min, y_range_max = -2_000, 15_000

FONTSIZE = 14
BLUE = (0.0, 0.4, 0.8)
fig, ax = plt.subplots(figsize=(4, 3))
ax.errorbar(x=x, y=y, yerr=y_err, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
ax.set_xlim(0, 70)
ax.tick_params(labelsize=FONTSIZE, direction="in", length=5, width=1)
ax.set_xlabel(r"Computational ranking", fontsize=FONTSIZE)
ax.set_ylabel(r"$K_{ass}^{exp}$ ($M^{-1}$)", fontsize=FONTSIZE)
# ax.set_xlim(x_range_min, x_range_max)
# ax.set_ylim(y_range_min, y_range_max)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
# ax.axhline(y=0, lw=1, color="k")
plt.savefig("kexp_vs_rank.png", format="png", dpi=300, bbox_inches="tight")
plt.savefig("kexp_vs_rank.svg", format="svg", bbox_inches="tight")
plt.show()
plt.close()

# %%
x
# Out:
# PRO-LEU     6.0
# PHE-SER    21.0
# GLY-ILE    12.0
# PRO-PRO    35.0
# PHE-LEU    62.0
# LEU-LEU    40.0
# TRP-GLN    39.0
# PRO-ALA    43.0
# GLN-GLN    14.0
# GLN-ALA    47.0
# Name: rank, dtype: float64

# %%
exp_test
# Out:
#         Training/Test  KA exp (1/M)  KA exp std  DG (kcal/mol)  \
# PRO-LEU          Test       11580.0      3056.0      -5.544933
# PHE-SER          Test        5673.0      5018.0      -5.114723
# GLY-ILE          Test        4184.0      2793.0      -4.947419
# PRO-PRO          Test        2917.0      1061.0      -4.732314
# PHE-LEU          Test        4747.0      1711.0      -5.019120
# LEU-LEU          Test        2120.0       958.0      -4.517208
# TRP-GLN          Test        2512.0      1163.0      -4.636711
# PRO-ALA          Test        2532.0      1072.0      -4.636711
# GLN-GLN          Test        3367.0      1214.0      -4.804015
# GLN-ALA          Test        2550.0       986.0      -4.636711
#
#          DG std (kcal/mol)
# PRO-LEU           0.143403
# PHE-SER           0.788719
# GLY-ILE           0.788719
# PRO-PRO           0.597514
# PHE-LEU           0.382409
# LEU-LEU           0.956023
# TRP-GLN           0.860421
# PRO-ALA           0.764818
# GLN-GLN           0.525813
# GLN-ALA           0.693117

# %%
x = test_data.loc[exp_test.index, ["W Q2", "W Q2_adj", "rank", "W sem"]].sort_values(by="rank")
for i, (q2, q2_adj, r, sem) in x.iterrows():
    print(f"{q2_adj:.2f} ± {sem*0.26:.2f}")
# test_data.loc[:, ["W Q2", "W Q2_adj", "rank", "W sem"]].sort_values(by="rank")
# test_data.loc[:, ["W Q2", "W Q2_adj", "rank", "W sem"]].sort_values(by="rank") * 0.26
# Out:
# -8.39 ± 0.29
# -8.10 ± 0.35
# -8.06 ± 0.68
# -7.93 ± 0.36
# -7.80 ± 0.37
# -7.76 ± 0.51
# -7.73 ± 0.63
# -7.64 ± 0.27
# -7.60 ± 0.38
# -7.39 ± 0.54

# %%
y = exp_test.loc[:, "DG (kcal/mol)"].abs()
y_err = exp_test.loc[:, "DG (kcal/mol)"]
x = test_data.loc[y.index, "rank"].abs()

# x_range_min, x_range_max = 0, 100
# y_range_min, y_range_max = 18, 24

FONTSIZE = 14
BLUE = (0.0, 0.4, 0.8)
fig, ax = plt.subplots(figsize=(3, 3))
ax.errorbar(x=x, y=y, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
# ax.errorbar(x=x, y=y, yerr=y_err, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")

ax.tick_params(labelsize=FONTSIZE, direction="in", length=5, width=1)
ax.set_xlabel(r"Computational ranking", fontsize=FONTSIZE)
ax.set_ylabel(r"$\Delta G_{exp}$ ($kCal / mol$)", fontsize=FONTSIZE)
# ax.set_xlim(x_range_min, x_range_max)
# ax.set_ylim(y_range_min, y_range_max)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.axhline(y=0, lw=1, color="k")

plt.show()
plt.close()

# %%
test_col = ["KA W Q2_adj"]
test_col_err = ["KA W Q2 - Q1_adj", "KA W Q3 - Q2_adj"]

y = test_data.loc[exp_test.index, test_col].abs()
y_err = test_data.loc[exp_test.index, test_col_err].T
x = test_data.loc[exp_test.index, "rank"].abs()

x_range_min, x_range_max = 0, 75
y_range_min, y_range_max = 0, 2.5e6

FONTSIZE = 14
BLUE = (0.0, 0.4, 0.8)
fig, ax = plt.subplots(figsize=(4, 3))
ax.errorbar(x=x, y=y, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")
# ax.errorbar(x=x, y=y, yerr=y_err, fmt="o", color=BLUE, ecolor="k", elinewidth=1, capsize=3, mew=1, mec="k")

ax.tick_params(labelsize=FONTSIZE, direction="in", length=5, width=1)
ax.set_xlabel(r"Computational ranking", fontsize=FONTSIZE)
ax.set_ylabel(r"$K_{ass}^{comp}$ ($M^{-1}$)", fontsize=FONTSIZE)
ax.set_xlim(x_range_min, x_range_max)
ax.set_ylim(y_range_min, y_range_max)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.axhline(y=0, lw=1, color="k")
plt.savefig("kcomp_vs_rank.png", format="png", dpi=300, bbox_inches="tight")
plt.savefig("kcomp_vs_rank.svg", format="svg", bbox_inches="tight")
plt.show()
plt.close()

# %%
AA_ordered = ['Gln', 'Ser', 'Tyr', 'Trp', 'Phe', 'Ile', 'Leu', 'Ala', 'Pro', 'Gly']
cmap = "plasma_r"
FONTSIZE = 12

heat_matrix = np.zeros(shape=(len(AA_ordered), len(AA_ordered)), dtype="float")
for i, aa1 in enumerate(AA_ordered):
    for j, aa2 in enumerate(AA_ordered):
        key = "{}-{}".format(aa1, aa2).upper()
        heat_matrix[i, j] = test_data.loc[key, "W Q2_adj"]

dg_min, dg_max = -9, -6
dg_thresh = np.quantile(heat_matrix, 0.2)
# dg_thresh = 0
print(np.min(heat_matrix), np.max(heat_matrix))
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.imshow(heat_matrix, cmap=cmap, vmin=dg_min, vmax=dg_max)
ax.set_xticks(np.linspace(0, len(AA_ordered) - 1, len(AA_ordered)))
ax.set_xticks(np.linspace(-0.5, len(AA_ordered) - 0.5, len(AA_ordered) + 1), minor=True)
ax.set_xticklabels(AA_ordered)
ax.set_yticks(np.linspace(0, len(AA_ordered) - 1, len(AA_ordered)))
ax.set_yticks(np.linspace(-0.5, len(AA_ordered) - 0.5, len(AA_ordered) + 1), minor=True)
ax.set_yticklabels(AA_ordered)
ax.tick_params(labelsize=FONTSIZE, size=0, width=1.6, direction="in", which="both")
ax.set_ylabel(r"$A_1$", fontsize=FONTSIZE + 2)
ax.set_xlabel(r"$A_2$", fontsize=FONTSIZE + 2)
ax.xaxis.grid(which='minor', lw=2, c='k')
ax.yaxis.grid(which='minor', lw=2, c='k')

for i, aa1 in enumerate(AA_ordered):
    for j, aa2 in enumerate(AA_ordered):
        dg = heat_matrix[i, j]
        if dg <= dg_thresh:
            ax.text(j, i, f"{dg:.1f}", color='k', ha='center', va='center', fontsize=FONTSIZE)

a = plt.axes([0.95, 0.125, 0.04, 0.76])
cbar = fig.colorbar(cax, ax=a, cax=a)#, ticks=[30, 32, 34, 36, 38])
cbar.ax.tick_params(labelsize=FONTSIZE + 2, size=6, width=1., direction="out")
cbar.ax.set_ylabel(r"$W_{adj}$ (kCal / mol)", fontsize=FONTSIZE + 2)
cbar.ax.set_ylim(dg_min, dg_max)
plt.savefig("heat_map.png", format="png", dpi=300, bbox_inches="tight")
plt.savefig("heat_map.svg", format="svg", dpi=300, bbox_inches="tight")
plt.show()
plt.close()
# Out:
# -8.715741088854703 -6.011694597387198

# %%
from matplotlib import cm
FONTSIZE=12


colors = cm.terrain(np.linspace(0, 0.85, len(AA_ordered)))
faded_colors = [(*c[:3], 0.8) for c in colors]
faded_colors = [(*c[:3], 0.4) for c in colors]
bp = dict(linestyle='-', lw=1.5, color='k', facecolor='r')
fp = dict(marker='o', ms=8, ls='none', mec='k', mew=2)
mp = dict(ls='-', lw=1., color='k')
cp = dict(ls='-', lw=1.5, color='k')
wp = dict(ls='-', lw=1.5, color='k')

fig, axs = plt.subplots(figsize=(7, 5), ncols=1, nrows=2, gridspec_kw={'hspace': 0.4})
grouping_col = ['aa1', 'aa2']
xlabels = ['AA1', 'AA2']

xx = np.linspace(1, len(AA_ordered), len(AA_ordered))
for ax, g_col, xlab in zip(axs, grouping_col, xlabels):
    ax.set_ylabel(r"$W_{adj}$ (kCal / mol)", fontsize=FONTSIZE)
    ax.tick_params(labelsize=FONTSIZE, size=6, width=1.6)
    group = test_data.groupby(g_col)
    for (aa, g_aa), i, c, fc in zip(group, xx, colors, faded_colors):
        bpl = ax.boxplot(g_aa.loc[:, "W Q2_adj"].abs(), positions=[i], widths=0.6, patch_artist=True,
                            boxprops=bp, flierprops=fp, medianprops=mp, capprops=cp, whiskerprops=wp)
        bpl['boxes'][0].set_facecolor(c)
        bpl['fliers'][0].set_markerfacecolor(fc)
    ax.set_ylim(6, 9)
    ax.set_xlim(0.5, len(AA_ordered) + 0.5)

    ax.set_xticks(np.linspace(1, len(AA_ordered), len(AA_ordered)), minor=True)
    ax.set_xticklabels(AA_ordered, fontsize=FONTSIZE, minor=True)
    ax.tick_params(length=0, which='minor', labelsize=FONTSIZE)

    ax.set_xticks(np.linspace(1, len(AA_ordered) - 1, len(AA_ordered) - 1) + 0.5, minor=False)
    ax.set_xticklabels([], fontsize=FONTSIZE, minor=False)
    ax.tick_params(length=4, width=1, which='major', direction="in")
    ax.set_yticks([6, 7, 8, 9])
    ax.set_xlabel(xlab, fontsize=FONTSIZE)

    ax.grid(which="major")

plt.show()
plt.close()
